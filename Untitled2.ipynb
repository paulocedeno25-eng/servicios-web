# %%
# %%writefile index.html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Tu Nombre | Desarrollador de Soluciones Digitales</title>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.0.0/css/all.min.css">
#     <style>
#         /* Estilos Base */
#         body { margin: 0; font-family: 'Poppins', sans-serif; background: #0b0f19; color: #fff; line-height: 1.6; }
#
#         /* Animación de fondo */
#         .hero {
#             height: 100vh;
#             background: radial-gradient(circle at center, #1e293b 0%, #0b0f19 100%);
#             display: flex; flex-direction: column; justify-content: center; align-items: center; text-align: center;
#         }
#
#         /* Texto Neón */
#         h1 { font-size: 4rem; margin: 0; color: #00d2ff; text-shadow: 0 0 20px rgba(0,210,255,0.5); }
#         .subtitle { font-size: 1.5rem; color: #94a3b8; margin-bottom: 30px; }
#
#         /* Botón Llamativo */
#         .cta-button {
#             background: linear-gradient(45deg, #00d2ff, #3a7bd5);
#             color: white; padding: 15px 40px; text-decoration: none; border-radius: 50px;
#             font-weight: bold; transition: 0.3s; box-shadow: 0 4px 15px rgba(0,210,255,0.3);
#         }
#         .cta-button:hover { transform: scale(1.1); box-shadow: 0 6px 20px rgba(0,210,255,0.5); }
#
#         /* Tarjetas de Servicios */
#         .services { padding: 80px 20px; display: grid; grid-template-columns: repeat(auto-fit, minmax(280px, 1fr)); gap: 20px; max-width: 1200px; margin: auto; }
#         .card { background: #161b2a; padding: 30px; border-radius: 20px; border: 1px solid #2d3748; transition: 0.3s; }
#         .card:hover { border-color: #00d2ff; background: #1c2336; }
#         .card i { font-size: 2.5rem; color: #00d2ff; margin-bottom: 20px; }
#     </style>
# </head>
# <body>
#
#     <section class="hero">
#         <div class="badge" style="border: 1px solid #00d2ff; padding: 5px 15px; border-radius: 20px; color: #00d2ff; font-size: 0.8rem; margin-bottom: 20px;">DISPONIBLE PARA PROYECTOS</div>
#         <h1>Creamos Soluciones, <br> No Solo Webs.</h1>
#         <p class="subtitle">Especialista en Aplicaciones en la Nube y Automatización.</p>
#         <a href="https://wa.me/ESCRIBE_TU_NUMERO" class="cta-button">📩 Hablemos de tu proyecto</a>
#     </section>
#
#     <div class="services">
#         <div class="card">
#             <i class="fas fa-layer-group"></i>
#             <h3>Apps a Medida</h3>
#             <p>Sistemas de gestión de inventario y préstamos con base de datos en tiempo real.</p>
#         </div>
#         <div class="card">
#             <i class="fas fa-cloud"></i>
#             <h3>Integración Nube</h3>
#             <p>Conecto tus herramientas con Google Drive para que nunca pierdas información.</p>
#         </div>
#         <div class="card">
#             <i class="fas fa-mobile-alt"></i>
#             <h3>Diseño Adaptable</h3>
#             <p>Tu negocio se verá perfecto tanto en computadoras como en teléfonos móviles.</p>
#         </div>
#     </div>
#
# </body>
# </html>
# Out:
# Writing index.html
